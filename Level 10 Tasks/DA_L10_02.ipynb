# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
df = df.dropna(subset=['Survived'])
df['Age'].fillna(df['Age'].median(), inplace=True)
df['Fare'].fillna(df['Fare'].median(), inplace=True)

# %%
numerical_cols = ['Age', 'Fare', 'SibSp', 'Parch']
categorical_cols = ['Sex', 'Pclass', 'Embarked']

# %%
print(" T-Test (Numerical vs Survived)\n")
for col in numerical_cols:
    group1 = df[df['Survived'] == 1][col]
    group0 = df[df['Survived'] == 0][col]
   
    t_stat, p_val_t = ttest_ind(group1, group0)
    sig_t = " Significant" if p_val_t < 0.05 else " Not significant"
    
    z_stat, p_val_z = ztest(group1, group0)
    sig_z = " Significant" if p_val_z < 0.05 else "Not significant"
    
    print(f"{col} → T-test p = {p_val_t:.4f} ({sig_t}),Z-test p = {p_val_z:.4f} ({sig_z})")
# Out:
#  T-Test (Numerical vs Survived)
#
# Age → T-test p = 0.8699 ( Not significant),Z-test p = 0.8698 (Not significant)
# Fare → T-test p = 0.0001 ( Significant),Z-test p = 0.0001 ( Significant)
# SibSp → T-test p = 0.0411 ( Significant),Z-test p = 0.0405 ( Significant)
# Parch → T-test p = 0.0011 ( Significant),Z-test p = 0.0010 ( Significant)

# %%
print("\n Chi-Square Test (Categorical vs Survived)\n")
for col in categorical_cols:
    contingency = pd.crosstab(df[col], df['Survived'])
    chi2, p_val_chi, dof, expected = chi2_contingency(contingency)
    sig = " Significant" if p_val_chi < 0.05 else " Not significant"
    print(f"{col} → Chi-square p = {p_val_chi:.4f} ({sig})")
# Out:
#  Chi-Square Test (Categorical vs Survived)
#
# Sex → Chi-square p = 0.0000 ( Significant)
# Pclass → Chi-square p = 0.0352 ( Significant)
# Embarked → Chi-square p = 0.0304 ( Significant)
